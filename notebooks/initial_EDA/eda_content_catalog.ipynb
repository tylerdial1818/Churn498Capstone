# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine("postgresql+psycopg2://localhost:5430/retain_dev")

catalog = pd.read_sql(
    "SELECT * FROM content_catalog",
    engine
)

catalog.head()
# Out:
#    content_id            title   genre content_type  release_year  \
# 0  CNT_B08028  Action_Series_1  Action       series          2024
# 1  CNT_273835   Drama_Series_2   Drama       series          2017
# 2  CNT_471E13   Drama_Series_3   Drama       series          2025
# 3  CNT_2FBF0B    Drama_Movie_4   Drama        movie          2021
# 4  CNT_72B309   Drama_Series_5   Drama       series          2017
#
#    duration_minutes
# 0                30
# 1                63
# 2                56
# 3               135
# 4                43
