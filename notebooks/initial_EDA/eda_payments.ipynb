# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine("postgresql+psycopg2://localhost:5430/retain_dev")

payments = pd.read_sql(
    "SELECT * FROM payments",
    engine
)

payments.head()
# Out:
#        payment_id    account_id payment_date  amount currency payment_method  \
# 0  PAY_C6C40B8F3D  ACC_728CCBB1   2024-01-08    9.99      USD     debit_card
# 1  PAY_16068148A4  ACC_728CCBB1   2024-02-07    9.99      USD     debit_card
# 2  PAY_032CC6B809  ACC_728CCBB1   2024-03-08    9.99      USD     debit_card
# 3  PAY_C27EFB23DC  ACC_728CCBB1   2024-04-07    9.99      USD     debit_card
# 4  PAY_458069423D  ACC_728CCBB1   2024-05-07    9.99      USD     debit_card
#
#     status      failure_reason
# 0   failed  insufficient_funds
# 1  success                 NaN
# 2  success                 NaN
# 3  success                 NaN
# 4  success                 NaN
