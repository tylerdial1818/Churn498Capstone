# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine("postgresql+psycopg2://localhost:5430/retain_dev")

subscriptions = pd.read_sql(
    "SELECT * FROM subscriptions",
    engine
)

subscriptions.head()
# Out:
#   subscription_id    account_id             plan_type  start_date    end_date  \
# 0  SUB_B322BEEE56  ACC_728CCBB1               Regular  2024-01-01        None
# 1  SUB_3809EDB4B0  ACC_747CFF0B  Premium-Multi-Screen  2024-01-20        None
# 2  SUB_72A2E45758  ACC_C8E9D207               Regular  2024-01-28        None
# 3  SUB_3E5B7FD5C7  ACC_2D5C4D35               Premium  2024-01-04        None
# 4  SUB_BB33E9852A  ACC_7C7AA7DC  Premium-Multi-Screen  2024-01-25  2025-09-03
#
#       status cancel_reason previous_plan  parental_control_enabled  \
# 0     active           NaN           NaN                     False
# 1     active           NaN           NaN                      True
# 2     active           NaN           NaN                     False
# 3     active           NaN           NaN                     False
# 4  cancelled     not_using           NaN                     False
#
#    watchlist_size  app_rating app_review_text
# 0              10         4.0             NaN
# 1               0         NaN             NaN
# 2              27         NaN             NaN
# 3               0         NaN             NaN
# 4               0         NaN             NaN
